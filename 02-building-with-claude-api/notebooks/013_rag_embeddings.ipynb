# %%
# Install VoyageAI lib
# %pip install voyageai
# Out:
# Collecting voyageai
#   Downloading voyageai-0.3.7-py3-none-any.whl.metadata (2.9 kB)
# Collecting aiohttp (from voyageai)
#   Downloading aiohttp-3.13.5-cp313-cp313-win_amd64.whl.metadata (8.4 kB)
# Collecting aiolimiter (from voyageai)
#   Downloading aiolimiter-1.2.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting ffmpeg-python (from voyageai)
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting langchain-text-splitters>=0.3.8 (from voyageai)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Collecting numpy>=2.1.0 (from voyageai)
#   Downloading numpy-2.4.5-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Collecting pillow (from voyageai)
#   Downloading pillow-12.2.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: pydantic>=1.10.8 in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from voyageai) (2.13.3)
# Requirement already satisfied: requests in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from voyageai) (2.33.1)
# Collecting tenacity (from voyageai)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting tokenizers>=0.14.0 (from voyageai)
#   Downloading tokenizers-0.23.1-cp310-abi3-win_amd64.whl.metadata (10 kB)
# Collecting langchain-core<2.0.0,>=1.2.31 (from langchain-text-splitters>=0.3.8->voyageai)
#   Downloading langchain_core-1.4.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-protocol>=0.0.14 (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai)
#   Downloading langchain_protocol-0.0.15-py3-none-any.whl.metadata (2.4 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai)
#   Downloading langsmith-0.8.5-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai)
#   Downloading uuid_utils-0.15.0-cp313-cp313-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (0.28.1)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai)
#   Downloading orjson-3.11.9-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting xxhash>=3.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai)
#   Downloading xxhash-3.7.0-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai)
#   Downloading zstandard-0.25.0-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (4.13.0)
# Requirement already satisfied: certifi in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (1.0.9)
# Requirement already satisfied: idna in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (3.13)
# Requirement already satisfied: h11>=0.16 in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters>=0.3.8->voyageai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from pydantic>=1.10.8->voyageai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from pydantic>=1.10.8->voyageai) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from pydantic>=1.10.8->voyageai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from requests->voyageai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from requests->voyageai) (2.6.3)
# Collecting huggingface-hub<2.0,>=0.16.4 (from tokenizers>=0.14.0->voyageai)
#   Downloading huggingface_hub-1.15.0-py3-none-any.whl.metadata (14 kB)
# Collecting filelock>=3.10.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Downloading filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Downloading fsspec-2026.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Downloading hf_xet-1.5.0-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting tqdm>=4.42.1 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting typer>=0.20.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Downloading typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: colorama in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (0.4.6)
# Collecting click>=8.2.1 (from typer>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Downloading click-8.4.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=13.8.0 (from typer>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.14.0->voyageai)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp->voyageai)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp->voyageai)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\paulk\mendix\claude training\venv\lib\site-packages (from aiohttp->voyageai) (26.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->voyageai)
#   Downloading frozenlist-1.8.0-cp313-cp313-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->voyageai)
#   Downloading multidict-6.7.1-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp->voyageai)
#   Downloading propcache-0.5.2-cp313-cp313-win_amd64.whl.metadata (17 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->voyageai)
#   Downloading yarl-1.23.0-cp313-cp313-win_amd64.whl.metadata (82 kB)
# Collecting future (from ffmpeg-python->voyageai)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Downloading voyageai-0.3.7-py3-none-any.whl (34 kB)
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Downloading langchain_core-1.4.0-py3-none-any.whl (548 kB)
#    ---------------------------------------- 0.0/548.1 kB ? eta -:--:--
#    ---------------------------------------- 548.1/548.1 kB 29.7 MB/s  0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.8.5-py3-none-any.whl (399 kB)
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading uuid_utils-0.15.0-cp313-cp313-win_amd64.whl (174 kB)
# Downloading langchain_protocol-0.0.15-py3-none-any.whl (7.0 kB)
# Downloading numpy-2.4.5-cp313-cp313-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 12.3/12.3 MB 83.4 MB/s  0:00:00
# Downloading orjson-3.11.9-cp313-cp313-win_amd64.whl (127 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading tokenizers-0.23.1-cp310-abi3-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 2.8/2.8 MB 92.8 MB/s  0:00:00
# Downloading huggingface_hub-1.15.0-py3-none-any.whl (663 kB)
#    ---------------------------------------- 0.0/663.6 kB ? eta -:--:--
#    ---------------------------------------- 663.6/663.6 kB 42.9 MB/s  0:00:00
# Downloading hf_xet-1.5.0-cp37-abi3-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 4.0/4.0 MB 89.1 MB/s  0:00:00
# Downloading filelock-3.29.0-py3-none-any.whl (39 kB)
# Downloading fsspec-2026.4.0-py3-none-any.whl (203 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading typer-0.25.1-py3-none-any.whl (58 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading click-8.4.0-py3-none-any.whl (116 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading xxhash-3.7.0-cp313-cp313-win_amd64.whl (31 kB)
# Downloading zstandard-0.25.0-cp313-cp313-win_amd64.whl (506 kB)
# Downloading aiohttp-3.13.5-cp313-cp313-win_amd64.whl (458 kB)
# Downloading multidict-6.7.1-cp313-cp313-win_amd64.whl (45 kB)
# Downloading yarl-1.23.0-cp313-cp313-win_amd64.whl (87 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp313-cp313-win_amd64.whl (43 kB)
# Downloading propcache-0.5.2-cp313-cp313-win_amd64.whl (41 kB)
# Downloading aiolimiter-1.2.1-py3-none-any.whl (6.7 kB)
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Downloading pillow-12.2.0-cp313-cp313-win_amd64.whl (7.1 MB)
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ---------------------------------------- 7.1/7.1 MB 100.6 MB/s  0:00:00
# Installing collected packages: zstandard, xxhash, uuid-utils, tqdm, tenacity, shellingham, propcache, pillow, orjson, numpy, multidict, mdurl, langchain-protocol, jsonpatch, hf-xet, future, fsspec, frozenlist, filelock, click, annotated-doc, aiolimiter, aiohappyeyeballs, yarl, requests-toolbelt, markdown-it-py, ffmpeg-python, aiosignal, rich, langsmith, aiohttp, typer, langchain-core, langchain-text-splitters, huggingface-hub, tokenizers, voyageai
#
#    --- ------------------------------------  3/37 [tqdm]
#    --- ------------------------------------  3/37 [tqdm]
#    ---- -----------------------------------  4/37 [tenacity]
#    ------- --------------------------------  7/37 [pillow]
#    ------- --------------------------------  7/37 [pillow]
#    ------- --------------------------------  7/37 [pillow]
#    ------- --------------------------------  7/37 [pillow]
#    ------- --------------------------------  7/37 [pillow]
#    ------- --------------------------------  7/37 [pillow]
#    -------- -------------------------------  8/37 [orjson]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    --------- ------------------------------  9/37 [numpy]
#    ---------- ----------------------------- 10/37 [multidict]
#    -------------- ------------------------- 13/37 [jsonpatch]
#    ---------------- ----------------------- 15/37 [future]
#    ---------------- ----------------------- 15/37 [future]
#    ---------------- ----------------------- 15/37 [future]
#    ---------------- ----------------------- 15/37 [future]
#    ---------------- ----------------------- 15/37 [future]
#    ---------------- ----------------------- 15/37 [future]
#    ---------------- ----------------------- 15/37 [future]
#    ---------------- ----------------------- 15/37 [future]
#    ---------------- ----------------------- 15/37 [future]
#    ---------------- ----------------------- 15/37 [future]
#    ----------------- ---------------------- 16/37 [fsspec]
#    ----------------- ---------------------- 16/37 [fsspec]
#    ----------------- ---------------------- 16/37 [fsspec]
#    ------------------ --------------------- 17/37 [frozenlist]
#    -------------------- ------------------- 19/37 [click]
#    --------------------- ------------------ 20/37 [annotated-doc]
#    ------------------------ --------------- 23/37 [yarl]
#    ------------------------- -------------- 24/37 [requests-toolbelt]
#    --------------------------- ------------ 25/37 [markdown-it-py]
#    --------------------------- ------------ 25/37 [markdown-it-py]
#    --------------------------- ------------ 25/37 [markdown-it-py]
#    --------------------------- ------------ 25/37 [markdown-it-py]
#    ------------------------------ --------- 28/37 [rich]
#    ------------------------------ --------- 28/37 [rich]
#    ------------------------------ --------- 28/37 [rich]
#    ------------------------------ --------- 28/37 [rich]
#    ------------------------------ --------- 28/37 [rich]
#    ------------------------------- -------- 29/37 [langsmith]
#    ------------------------------- -------- 29/37 [langsmith]
#    ------------------------------- -------- 29/37 [langsmith]
#    ------------------------------- -------- 29/37 [langsmith]
#    ------------------------------- -------- 29/37 [langsmith]
#    ------------------------------- -------- 29/37 [langsmith]
#    -------------------------------- ------- 30/37 [aiohttp]
#    -------------------------------- ------- 30/37 [aiohttp]
#    -------------------------------- ------- 30/37 [aiohttp]
#    -------------------------------- ------- 30/37 [aiohttp]
#    --------------------------------- ------ 31/37 [typer]
#    ---------------------------------- ----- 32/37 [langchain-core]
#    ---------------------------------- ----- 32/37 [langchain-core]
#    ---------------------------------- ----- 32/37 [langchain-core]
#    ---------------------------------- ----- 32/37 [langchain-core]
#    ---------------------------------- ----- 32/37 [langchain-core]
#    ---------------------------------- ----- 32/37 [langchain-core]
#    ---------------------------------- ----- 32/37 [langchain-core]
#    ---------------------------------- ----- 32/37 [langchain-core]
#    ---------------------------------- ----- 32/37 [langchain-core]
#    ---------------------------------- ----- 32/37 [langchain-core]
#    ---------------------------------- ----- 32/37 [langchain-core]
#    ------------------------------------ --- 34/37 [huggingface-hub]
#    ------------------------------------ --- 34/37 [huggingface-hub]
#    ------------------------------------ --- 34/37 [huggingface-hub]
#    ------------------------------------ --- 34/37 [huggingface-hub]
#    ------------------------------------ --- 34/37 [huggingface-hub]
#    ------------------------------------ --- 34/37 [huggingface-hub]
#    ------------------------------------ --- 34/37 [huggingface-hub]
#    ------------------------------------ --- 34/37 [huggingface-hub]
#    ------------------------------------ --- 34/37 [huggingface-hub]
#    ------------------------------------ --- 34/37 [huggingface-hub]
#    ------------------------------------ --- 34/37 [huggingface-hub]
#    ------------------------------------ --- 34/37 [huggingface-hub]
#    ------------------------------------- -- 35/37 [tokenizers]
#    -------------------------------------- - 36/37 [voyageai]
#    ---------------------------------------- 37/37 [voyageai]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aiolimiter-1.2.1 aiosignal-1.4.0 annotated-doc-0.0.4 click-8.4.0 ffmpeg-python-0.2.0 filelock-3.29.0 frozenlist-1.8.0 fsspec-2026.4.0 future-1.0.0 hf-xet-1.5.0 huggingface-hub-1.15.0 jsonpatch-1.33 langchain-core-1.4.0 langchain-protocol-0.0.15 langchain-text-splitters-1.1.2 langsmith-0.8.5 markdown-it-py-4.2.0 mdurl-0.1.2 multidict-6.7.1 numpy-2.4.5 orjson-3.11.9 pillow-12.2.0 propcache-0.5.2 requests-toolbelt-1.0.0 rich-15.0.0 shellingham-1.5.4 tenacity-9.1.4 tokenizers-0.23.1 tqdm-4.67.3 typer-0.25.1 uuid-utils-0.15.0 voyageai-0.3.7 xxhash-3.7.0 yarl-1.23.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Client Setup
from dotenv import load_dotenv
import voyageai

load_dotenv()

client = voyageai.Client()

# %%
# Chunk by section
import re


def chunk_by_section(document_text):
    pattern = r"\n## "
    return re.split(pattern, document_text)

# %%
# Embedding Generation
def generate_embedding(text, model="voyage-3-large", input_type="query"):
    result = client.embed([text], model=model, input_type=input_type)

    return result.embeddings[0]

# %%
with open("./report.md", "r") as f:
    text = f.read()

chunks = chunk_by_section(text)

generate_embedding(chunks[0])
