# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
        "solution_criteria": Specifics that must be included to make the task be succesful.
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()
#dataset <-- raw output

#save to file
with open("dataset_006.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Solution Criteria:
<solution_criteria>
{test_case["solution_criteria"]}
</solution_criteria>


Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """
    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* respond only with python, json or a plain regex.
* Do not add any comments, commentary or explanation
"""
    
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning
    }

# %%
from statistics import mean
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    avg_score = mean([result["score"] for result in results])
    print(f"Average score: {avg_score}")
    return results

# %%
with open("dataset_006.json", "r") as f:
    dataset = json.load(f)

results =run_eval(dataset)
# Out:
# Average score: 5.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser and Validator\n\n```python\nimport re\nfrom typing import Tuple, Optional\n\nclass S3BucketParser:\n    \"\"\"Parse and validate AWS S3 bucket names from S3 URIs.\"\"\"\n    \n    # AWS S3 naming rules:\n    # - 3-63 characters long\n    # - lowercase letters, numbers, hyphens, periods\n    # - must start and end with letter or number\n    # - no consecutive hyphens or periods\n    # - cannot be formatted as IP address\n    \n    BUCKET_NAME_PATTERN = re.compile(\n        r'^[a-z0-9]([a-z0-9\\.\\-]{1,61}[a-z0-9])?$'\n    )\n    \n    S3_URI_PATTERNS = {\n        'path_style': re.compile(r'^s3://([a-z0-9\\.\\-]+)(/.*)?$'),\n        'virtual_hosted': re.compile(r'^https?://([a-z0-9\\.\\-]+)\\.s3[.-].*\\.amazonaws\\.com(/.*)?$'),\n        'access_point': re.compile(r'^https?://([a-z0-9\\-]+)\\.s3\\..*\\.amazonaws\\.com(/.*)?$'),\n    }\n    \n    @staticmethod\n    def parse_bucket_name(s3_uri: str) -> Tuple[bool, Optional[str], str]:\n        \"\"\"\n        Parse bucket name from S3 URI.\n        \n        Args:\n            s3_uri: S3 URI in various formats (s3://, https://, etc.)\n            \n        Returns:\n            Tuple of (is_valid, bucket_name, message)\n        \"\"\"\n        if not s3_uri:\n            return False, None, \"S3 URI cannot be empty\"\n        \n        s3_uri = s3_uri.strip()\n        bucket_name = None\n        \n        # Try path-style: s3://bucket-name/key\n        match = S3BucketParser.S3_URI_PATTERNS['path_style'].match(s3_uri)\n        if match:\n            bucket_name = match.group(1)\n            return S3BucketParser.validate_bucket_name(bucket_name)\n        \n        # Try virtual-hosted-style: https://bucket-name.s3.region.amazonaws.com\n        match = S3BucketParser.S3_URI_PATTERNS['virtual_hosted'].match(s3_uri)\n        if match:\n            bucket_name = match.group(1)\n            return S3BucketParser.validate_bucket_name(bucket_name)\n        \n        # Try access point style\n        match = S3BucketParser.S3_URI_PATTERNS['access_point'].match(s3_uri)\n        if match:\n            bucket_name = match.group(1)\n            return S3BucketParser.validate_bucket_name(bucket_name)\n        \n        return False, None, \"Invalid S3 URI format. Expected s3://, https://, or http:// URI\"\n    \n    @staticmethod\n    def validate_bucket_name(bucket_name: str) -> Tuple[bool, Optional[str], str]:\n        \"\"\"\n        Validate bucket name against AWS naming conventions.\n        \n        Args:\n            bucket_name: The bucket name to validate\n            \n        Returns:\n            Tuple of (is_valid, bucket_name, message)\n        \"\"\"\n        if not bucket_name:\n            return False, None, \"Bucket name cannot be empty\"\n        \n        # Check length\n        if len(bucket_name) < 3:\n            return False, bucket_name, \"Bucket name must be at least 3 characters long\"\n        \n        if len(bucket_name) > 63:\n            return False, bucket_name, \"Bucket name must not exceed 63 characters\"\n        \n        # Check if it looks like an IP address\n        if S3BucketParser._is_ip_address(bucket_name):\n            return False, bucket_name, \"Bucket name cannot be formatted as an IP address\"\n        ",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from a full S3 URI and validate that it follows AWS naming conventions",
#       "format": "regex",
#       "solution_criteria": "Regex must extract bucket name from URIs like 's3://my-bucket-name/key/path', validate lowercase letters, numbers, hyphens, and be 3-63 characters long, without consecutive hyphens or starting/ending with hyphen"
#     },
#     "score": 3,
#     "reasoning": "The solution demonstrates good architectural design with multiple URI format support and proper method organization. However, it has critical flaws: (1) The regex allows consecutive hyphens/periods (e.g., 'my--bucket' and 'my..bucket' would pass), violating AWS naming conventions and explicit criteria; (2) The code is incomplete with missing `_is_ip_address()` method and no final return statement in `validate_bucket_name()`; (3) These are not minor issues - they prevent the code from functioning and fail the core validation requirements. The solution needed to either use a more restrictive regex with negative lookaheads or add explicit checks for consecutive characters."
#   },
#   {
#     "output": "# AWS CloudWatch Log Event Formatter\n\nHere's a comprehensive Python function that formats AWS CloudWatch log events:\n\n```python\nfrom datetime import datetime\nfrom typing import Dict, Any, Optional\n\ndef format_cloudwatch_log_event(\n    event: Dict[str, Any],\n    include_request_id: bool = False,\n    timezone_offset: Optional[int] = None\n) -> str:\n    \"\"\"\n    Format an AWS CloudWatch log event into a readable string.\n    \n    Args:\n        event: CloudWatch log event dictionary containing:\n            - message: The log message (required)\n            - timestamp: Unix timestamp in milliseconds (optional)\n        include_request_id: Whether to include request ID if present\n        timezone_offset: UTC offset in hours (e.g., -5 for EST)\n    \n    Returns:\n        Formatted log string\n    \n    Raises:\n        ValueError: If required fields are missing\n    \n    Example:\n        >>> event = {\n        ...     'timestamp': 1699564800000,\n        ...     'message': '[INFO] User login successful'\n        ... }\n        >>> print(format_cloudwatch_log_event(event))\n    \"\"\"\n    \n    if not isinstance(event, dict):\n        raise ValueError(\"Event must be a dictionary\")\n    \n    if 'message' not in event:\n        raise ValueError(\"Event must contain 'message' field\")\n    \n    message = event['message'].strip()\n    \n    # Parse timestamp\n    timestamp_str = _format_timestamp(event.get('timestamp'), timezone_offset)\n    \n    # Extract log level from message\n    log_level = _extract_log_level(message)\n    \n    # Build formatted string\n    formatted = f\"[{timestamp_str}] {log_level} {message}\"\n    \n    # Optionally add request ID\n    if include_request_id and 'requestId' in event:\n        formatted += f\" (RequestID: {event['requestId']})\"\n    \n    return formatted\n\n\ndef _format_timestamp(timestamp_ms: Optional[int], timezone_offset: Optional[int] = None) -> str:\n    \"\"\"Convert CloudWatch timestamp to readable format.\"\"\"\n    if timestamp_ms is None:\n        return datetime.now().strftime(\"%Y-%m-%d %H:%M:%S\")\n    \n    try:\n        # CloudWatch timestamps are in milliseconds\n        timestamp_sec = timestamp_ms / 1000\n        dt = datetime.utcfromtimestamp(timestamp_sec)\n        \n        if timezone_offset is not None:\n            from datetime import timedelta\n            dt = dt + timedelta(hours=timezone_offset)\n        \n        return dt.strftime(\"%Y-%m-%d %H:%M:%S\")\n    except (ValueError, TypeError, OSError):\n        return \"INVALID_TIMESTAMP\"\n\n\ndef _extract_log_level(message: str) -> str:\n    \"\"\"Extract log level from message if present, otherwise return generic level.\"\"\"\n    common_levels = ['DEBUG', 'INFO', 'WARN', 'WARNING', 'ERROR', 'CRITICAL', 'FATAL']\n    \n    # Check if message starts with a log level\n    for level in common_levels:\n        if message.startswith(f\"[{level}]\") or message.startswith(f\"{level}:\"):\n            return level\n    \n    # Check for common JSON-formatted logs\n    if '\"level\"' in message.lower() or '\"severity\"' in message.lower():\n        return \"JSON\"\n    \n    return \"INFO\"  # Default level\n\n\n# Alternative: More advanced version with JSON parsing\ndef format_cloudwatch_log_event_advanced(\n    event: Dict[str, Any],\n    pretty_print: bool = False\n) -> str:\n    \"\"\"\n    Advanced formatter that handles JSON-formatted logs.\n    \n    Args:\n        event: CloudWatch log event\n        pretty_print: Whether to pretty-print JSON content\n    \n    Returns:\n        Formatted log string\n    \"\"\"\n    import json\n    \n    if 'message' not in event:\n        raise ValueError(\"Event must contain 'message' field\")\n    \n    message = event['message'].strip()\n    timestamp_str = _format_timestamp(event.get",
#     "test_case": {
#       "task": "Write a Python function that formats an AWS CloudWatch log event into a readable string with timestamp, log level, and message",
#       "format": "python",
#       "solution_criteria": "Function must accept a CloudWatch log event dict, extract the timestamp (converting from milliseconds), log level, and message, and return a formatted string like '[2024-01-15 10:30:45] ERROR: Failed to connect to database'"
#     },
#     "score": 6,
#     "reasoning": "The solution demonstrates solid AWS knowledge and good software engineering practices with proper validation, helper functions, and documentation. However, it fails to fully meet the core requirement due to incomplete code. The timestamp handling has a deprecated method issue that could cause problems in future Python versions. Most critically, the log level extraction creates redundancy by keeping brackets in the original message while also extracting and prepending the level separately. The basic function works but the advanced variant is incomplete, and the log level handling needs refinement to match the specified output format exactly."
#   },
#   {
#     "output": "# S3 Read-Only IAM Policy\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"S3ReadOnlyAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\",\n        \"s3:GetObjectTagging\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-bucket-name/*\"\n    },\n    {\n      \"Sid\": \"S3ListBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketVersioning\",\n        \"s3:ListBucketVersions\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-bucket-name\"\n    }\n  ]\n}\n```\n\n## Key Components:\n\n| Component | Description |\n|-----------|-------------|\n| **Version** | Policy language version (always use \"2012-10-17\") |\n| **GetObject** | Read objects from the bucket |\n| **ListBucket** | List contents of the bucket |\n| **Resource ARN** | Replace `my-bucket-name` with your actual bucket name |\n| `/*` suffix | Applies to all objects within the bucket |\n\n## Usage Notes:\n\n- **Replace** `my-bucket-name` with your actual S3 bucket name\n- **No Put/Delete permissions** - ensures read-only access\n- **Two statements** - one for bucket operations, one for object operations\n- Attach this policy to an IAM user, role, or group as needed",
#     "test_case": {
#       "task": "Generate a JSON IAM policy document that grants read-only access to a specific S3 bucket",
#       "format": "json",
#       "solution_criteria": "JSON must be a valid IAM policy with proper Version, Statement array, Effect set to 'Allow', Actions limited to s3:GetObject and s3:ListBucket, and Resource restricted to a specific bucket ARN"
#     },
#     "score": 8,
#     "reasoning": "The solution meets core criteria with valid JSON, proper policy structure, and restricted resource ARNs. However, it goes beyond minimal read-only access by including versioning-related permissions that weren't required. The policy is secure (no Put/Delete), well-documented, and functional, but could be more minimal. For a strict 'read-only' interpretation, only s3:GetObject and s3:ListBucket are essential."
#   }
# ]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
