# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
        "solution_criteria": Specifics that must be included to make the task be succesful.
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()
#dataset <-- raw output

#save to file
with open("dataset_006.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Solution Criteria:
<solution_criteria>
{test_case["solution_criteria"]}
</solution_criteria>


Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """
    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* respond only with python, json or a plain regex.
* Do not add any comments, commentary or explanation
"""
    
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning
    }

# %%
from statistics import mean
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    avg_score = mean([result["score"] for result in results])
    print(f"Average score: {avg_score}")
    return results

# %%
with open("dataset_006.json", "r") as f:
    dataset = json.load(f)

results =run_eval(dataset)
# Out:
# Average score: 8.0

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\n{\n  \"FunctionName\": \"S3EventProcessor\",\n  \"Runtime\": \"python3.11\",\n  \"Role\": \"arn:aws:iam::ACCOUNT_ID:role/lambda-s3-role\",\n  \"Handler\": \"index.handler\",\n  \"Timeout\": 60,\n  \"MemorySize\": 256,\n  \"Environment\": {\n    \"Variables\": {\n      \"TARGET_BUCKET\": \"my-target-bucket\",\n      \"LOG_LEVEL\": \"INFO\"\n    }\n  },\n  \"Events\": {\n    \"S3Event\": {\n      \"Type\": \"S3\",\n      \"Properties\": {\n        \"Bucket\": \"my-source-bucket\",\n        \"Events\": [\"s3:ObjectCreated:*\", \"s3:ObjectRemoved:*\"],\n        \"Filter\": {\n          \"Key\": {\n            \"FilterRules\": [\n              {\n                \"Name\": \"prefix\",\n                \"Value\": \"uploads/\"\n              },\n              {\n                \"Name\": \"suffix\",\n                \"Value\": \".jpg\"\n              }\n            ]\n          }\n        }\n      }\n    }\n  },\n  \"VpcConfig\": {\n    \"SubnetIds\": [\"subnet-12345678\"],\n    \"SecurityGroupIds\": [\"sg-12345678\"]\n  },\n  \"Layers\": [],\n  \"Tags\": {\n    \"Environment\": \"production\",\n    \"Application\": \"s3-event-processor\"\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON configuration file for an AWS Lambda function that processes S3 events, with environment variables for the target bucket and log level",
#       "format": "json",
#       "solution_criteria": [
#         "Must include Lambda function metadata (name, runtime, role ARN)",
#         "Must contain an S3 event source mapping configuration",
#         "Must include environment variables for target bucket name and log level",
#         "Must specify valid AWS Lambda runtime (e.g., python3.11)",
#         "Must include proper JSON syntax and structure"
#       ]
#     },
#     "score": 8.5,
#     "reasoning": "The solution demonstrates strong understanding of Lambda configuration structure and includes all mandatory elements from the criteria. However, there's a critical architectural issue: the 'Events' section won't work as presented because AWS Lambda's API doesn't support event source mapping configuration in this format. S3 event notifications must be configured separately through the S3 bucket's notification settings. The configuration is otherwise production-ready but needs clarification on deployment methodology and placeholder substitution. If this is intended as SAM/CloudFormation template syntax, it should be explicitly labeled as such."
#   },
#   {
#     "output": "\nimport json\n\ndef validate_iam_policy(policy_document):\n    try:\n        if isinstance(policy_document, str):\n            policy = json.loads(policy_document)\n        else:\n            policy = policy_document\n        \n        if not isinstance(policy, dict):\n            return False\n        \n        statements = policy.get('Statement', [])\n        \n        if not isinstance(statements, list) or len(statements) == 0:\n            return False\n        \n        for statement in statements:\n            if not isinstance(statement, dict):\n                return False\n            \n            has_principal = 'Principal' in statement\n            has_effect = 'Effect' in statement\n            has_action = 'Action' in statement\n            \n            if has_principal and has_effect and has_action:\n                return True\n        \n        return False\n    \n    except (json.JSONDecodeError, TypeError, AttributeError):\n        return False\n\n\nif __name__ == \"__main__\":\n    valid_policy = {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Principal\": \"*\",\n                \"Effect\": \"Allow\",\n                \"Action\": \"s3:GetObject\",\n                \"Resource\": \"arn:aws:s3:::mybucket/*\"\n            }\n        ]\n    }\n    \n    invalid_policy = {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"s3:GetObject\"\n            }\n        ]\n    }\n    \n    print(validate_iam_policy(valid_policy))\n    print(validate_iam_policy(invalid_policy))\n",
#     "test_case": {
#       "task": "Write a Python function that validates an AWS IAM policy document by checking if it contains at least one Principal, Effect, and Action statement, then returns True or False",
#       "format": "python",
#       "solution_criteria": [
#         "Function must accept a dictionary or JSON string as input",
#         "Must check for presence of 'Principal', 'Effect', and 'Action' keys",
#         "Must return a boolean value",
#         "Must handle both valid and invalid policy structures gracefully",
#         "Should work with nested Statement arrays in IAM policies"
#       ]
#     },
#     "score": 7.5,
#     "reasoning": "The solution meets 4 of 5 criteria but has a critical semantic flaw: it incorrectly requires Principal in all statements. AWS IAM policies come in two types\u2014identity-based (no Principal required) and resource-based (Principal required). The current implementation would reject many valid identity-based policies. Additionally, the function doesn't validate that Action and Resource contain meaningful values, only that the keys exist. The error handling is solid, but the core validation logic doesn't align with AWS IAM policy specifications."
#   },
#   {
#     "output": "\n^[a-z0-9]([a-z0-9-]{1,61}[a-z0-9])?$\n",
#     "test_case": {
#       "task": "Create a regular expression pattern that matches valid AWS S3 bucket names according to AWS naming rules (3-63 characters, lowercase letters, numbers, hyphens, must start and end with lowercase letter or number)",
#       "format": "regex",
#       "solution_criteria": [
#         "Must enforce length constraint of 3-63 characters",
#         "Must only allow lowercase letters (a-z), numbers (0-9), and hyphens (-)",
#         "Must require the name to start with a lowercase letter or number",
#         "Must require the name to end with a lowercase letter or number",
#         "Must not allow consecutive hyphens or hyphens at start/end",
#         "Should be a single regex pattern that can be compiled and tested"
#       ]
#     },
#     "score": 8.0,
#     "reasoning": "The regex correctly addresses 4 of 6 criteria: character restrictions, start/end requirements, no consecutive hyphens, and valid compilation. However, it has a critical flaw in length validation. The pattern `^[a-z0-9]([a-z0-9-]{1,61}[a-z0-9])?$` makes the middle and end portions optional with `?`, which means 'ab' matches (1 char + optional group not present). AWS requires a minimum of 3 characters, so this is a functional defect. To fix this, the pattern should be `^[a-z0-9]([a-z0-9-]{0,61}[a-z0-9]|[a-z0-9])$` to handle both 2+ char names and single-char edge cases properly, or simpler: require at least 3 characters explicitly."
#   }
# ]
