# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()
#dataset <-- raw output

#save to file
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """
    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning
    }

# %%
from statistics import mean
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    avg_score = mean([result["score"] for result in results])
    print(f"Average score: {avg_score}")
    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results =run_eval(dataset)
# Out:
# Average score: 7.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 URI Parser\n\nHere's a Python function that parses AWS S3 bucket URIs:\n\n```python\ndef parse_s3_uri(uri: str) -> dict:\n    \"\"\"\n    Parse an AWS S3 bucket URI and return bucket and key components.\n    \n    Args:\n        uri (str): S3 URI in the format 's3://bucket-name/path/to/file'\n        \n    Returns:\n        dict: Dictionary with 'bucket' and 'key' fields\n        \n    Raises:\n        ValueError: If the URI is not a valid S3 URI\n        \n    Example:\n        >>> parse_s3_uri('s3://my-bucket/path/to/file.txt')\n        {'bucket': 'my-bucket', 'key': 'path/to/file.txt'}\n    \"\"\"\n    if not isinstance(uri, str):\n        raise ValueError(\"URI must be a string\")\n    \n    if not uri.startswith('s3://'):\n        raise ValueError(\"URI must start with 's3://'\")\n    \n    # Remove the 's3://' prefix\n    uri_without_prefix = uri[5:]\n    \n    # Split on the first '/' to separate bucket from key\n    if '/' not in uri_without_prefix:\n        raise ValueError(\"URI must contain a key after the bucket name (e.g., 's3://bucket/key')\")\n    \n    bucket, key = uri_without_prefix.split('/', 1)\n    \n    if not bucket:\n        raise ValueError(\"Bucket name cannot be empty\")\n    \n    if not key:\n        raise ValueError(\"Key cannot be empty\")\n    \n    return {\n        'bucket': bucket,\n        'key': key\n    }\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Valid cases\n    print(\"Valid cases:\")\n    print(parse_s3_uri('s3://my-bucket/path/to/file.txt'))\n    # Output: {'bucket': 'my-bucket', 'key': 'path/to/file.txt'}\n    \n    print(parse_s3_uri('s3://data-lake/2024/01/15/data.csv'))\n    # Output: {'bucket': 'data-lake', 'key': '2024/01/15/data.csv'}\n    \n    print(parse_s3_uri('s3://logs/application.log'))\n    # Output: {'bucket': 'logs', 'key': 'application.log'}\n    \n    # Invalid cases\n    print(\"\\nInvalid cases:\")\n    test_cases = [\n        'http://my-bucket/file.txt',  # Wrong protocol\n        'my-bucket/file.txt',          # Missing s3://\n        's3://my-bucket',              # Missing key\n        's3:///file.txt',              # Missing bucket\n        '',                            # Empty string\n    ]\n    \n    for test in test_cases:\n        try:\n            parse_s3_uri(test)\n        except ValueError as e:\n            print(f\"\u274c '{test}' -> Error: {e}\")\n```\n\n**Output:**\n```\nValid cases:\n{'bucket': 'my-bucket', 'key': 'path/to/file.txt'}\n{'bucket': 'data-lake', 'key': '2024/01/15/data.csv'}\n{'bucket': 'logs', 'key': 'application.log'}\n\nInvalid cases:\n\u274c 'http://my-bucket/file.txt' -> Error: URI must start with 's3://'\n\u274c 'my-bucket/file.txt' -> Error: URI must start with 's3://'\n\u274c 's3://my-bucket' -> Error: URI must contain a key after the bucket name (e.g., 's3://bucket/key')\n\u274c 's3:///file.txt' -> Error: Bucket name cannot be empty\n\u274c '' -> Error: URI must start with 's3://'\n```\n\n## Alternative: Using `urllib.parse`\n\nIf you prefer a more robust approach using Python's standard library:\n\n```python\nfrom urllib.parse import urlparse\n\ndef parse_",
#     "test_case": {
#       "task": "Write a Python function that parses an AWS S3 bucket URI (e.g., 's3://my-bucket/path/to/file.txt') and returns a dictionary with 'bucket' and 'key' as separate fields."
#     },
#     "score": 7,
#     "reasoning": "The primary solution is solid and production-ready for basic S3 URI parsing with robust error handling and clear documentation. However, the response is incomplete with a dangling alternative section, and it lacks AWS-specific bucket name validation. The core function correctly handles the stated requirements but could be more defensive about edge cases like trailing slashes. The incomplete second approach significantly detracts from the overall presentation."
#   },
#   {
#     "output": "# AWS IAM Read-Only S3 Bucket Policy\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ReadOnlyAccessToCompanyDataBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::company-data/*\"\n    },\n    {\n      \"Sid\": \"ListCompanyDataBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketVersioning\"\n      ],\n      \"Resource\": \"arn:aws:s3:::company-data\"\n    }\n  ]\n}\n```\n\n## Explanation\n\nThis policy includes two statements:\n\n1. **ReadOnlyAccessToCompanyDataBucket**\n   - Allows `GetObject` and `GetObjectVersion` actions\n   - Applied to all objects within the bucket (`/*`)\n   - Enables users to read and download files\n\n2. **ListCompanyDataBucket**\n   - Allows `ListBucket` to view bucket contents\n   - Allows `GetBucketVersioning` to check versioning status\n   - Applied to the bucket itself (without `/*`)\n   - Enables users to see what files exist\n\nThis provides complete read-only access while preventing any write, delete, or modification operations.",
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to a specific S3 bucket named 'company-data'."
#     },
#     "score": 7,
#     "reasoning": "The policy correctly implements fundamental read-only S3 access with proper ARN targeting and statement separation. The core permissions (GetObject, ListBucket) are well-chosen and functional. However, the inclusion of GetBucketVersioning without justification and potential gaps in object metadata access actions (tags, ACLs) suggest the solution may not cover all realistic read-only scenarios. The policy is solid for basic use cases but could be more comprehensive."
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regular Expression\n\nHere's the correct regular expression:\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Explanation\n\n- `^` - Start of string anchor\n- `i-` - Literal \"i-\" prefix (required for all EC2 instance IDs)\n- `[0-9a-f]{17}` - Exactly 17 hexadecimal characters (0-9 and a-f)\n- `$` - End of string anchor\n\n## Examples\n\n### Valid matches:\n- `i-0a1b2c3d4e5f6g7h8` \u274c (contains 'g' and 'h' - not hex)\n- `i-0a1b2c3d4e5f67890` \u2705\n- `i-1234567890abcdef0` \u2705\n\n### Invalid matches:\n- `i-0a1b2c3d4e5f6g7h8` \u274c (non-hex characters)\n- `i-0a1b2c3d4e5f67` \u274c (only 14 hex chars)\n- `0a1b2c3d4e5f67890` \u274c (missing \"i-\" prefix)\n\n## Language-Specific Examples\n\n**Python:**\n```python\nimport re\npattern = r'^i-[0-9a-f]{17}$'\nif re.match(pattern, instance_id):\n    print(\"Valid EC2 instance ID\")\n```\n\n**JavaScript:**\n```javascript\nconst pattern = /^i-[0-9a-f]{17}$/;\nif (pattern.test(instanceId)) {\n    console.log(\"Valid EC2 instance ID\");\n}\n```\n\n**Note:** Your example contains 'g' and 'h' which aren't valid hexadecimal characters. Valid hex is only 0-9 and a-f.",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs (format: i- followed by 17 hexadecimal characters, e.g., i-0a1b2c3d4e5f6g7h8)."
#     },
#     "score": 7,
#     "reasoning": "The solution demonstrates solid regex knowledge with a technically correct pattern for lowercase hex characters. However, the conflicting example that marks an invalid ID as valid significantly undermines clarity and could mislead users. More importantly, the solution doesn't account for uppercase hexadecimal characters that AWS actually accepts in real-world EC2 instance IDs, which is a practical limitation for production code."
#   }
# ]
